# %% [markdown]
# ### Acquiring data and libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os

# Path of the file to read

df = pd.read_csv('DATA HANDLING.csv')

# %% [markdown]
# ### Showing all features available in the data

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %% [markdown]
# ### Displaying categotical and numerical features in the data

# %% [markdown]
# #### Categorical data

# %%
df[['Sex', 'Embarked']].head()
# Out:
#       Sex Embarked
# 0    male        S
# 1  female        C
# 2  female        S
# 3  female        S
# 4    male        S

# %% [markdown]
# #### Numerical data

# %%
df[['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare']]
# Out:
#      PassengerId  Survived  Pclass    Age  SibSp  Parch              Ticket  \
# 0              1         0       3  22.00      1      0           A/5 21171
# 1              2         1       1  38.00      1      0            PC 17599
# 2              3         1       3  26.00      0      0    STON/O2. 3101282
# 3              4         1       1  35.00      1      0              113803
# 4              5         0       3  35.00      0      0              373450
# 5              6         0       3    NaN      0      0              330877
# 6              7         0       1  54.00      0      0               17463
# 7              8         0       3   2.00      3      1              349909
# 8              9         1       3  27.00      0      2              347742
# 9             10         1       2  14.00      1      0              237736
# 10            11         1       3   4.00      1      1             PP 9549
# ...

# %% [markdown]
# #### Numberic and alphanumeric data types

# %%
df[['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin']]
# Out:
#      PassengerId  Survived  Pclass    Age  SibSp  Parch              Ticket  \
# 0              1         0       3  22.00      1      0           A/5 21171
# 1              2         1       1  38.00      1      0            PC 17599
# 2              3         1       3  26.00      0      0    STON/O2. 3101282
# 3              4         1       1  35.00      1      0              113803
# 4              5         0       3  35.00      0      0              373450
# 5              6         0       3    NaN      0      0              330877
# 6              7         0       1  54.00      0      0               17463
# 7              8         0       3   2.00      3      1              349909
# 8              9         1       3  27.00      0      2              347742
# 9             10         1       2  14.00      1      0              237736
# 10            11         1       3   4.00      1      1             PP 9549
# ...

# %% [markdown]
# #### Columns with NaN values

# %%
# Finds columns with NaN values

df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          688
# Embarked         2
# dtype: int64

# %%
df[['Age', 'Cabin', 'Embarked']]
# Out:
#        Age            Cabin Embarked
# 0    22.00              NaN        S
# 1    38.00              C85        C
# 2    26.00              NaN        S
# 3    35.00             C123        S
# 4    35.00              NaN        S
# 5      NaN              NaN        Q
# 6    54.00              E46        S
# 7     2.00              NaN        S
# 8    27.00              NaN        S
# 9    14.00              NaN        C
# 10    4.00               G6        S
# 11   58.00             C103        S
# 12   20.00              NaN        S
# 13   39.00              NaN        S
# 14   14.00              NaN        S
# 15   55.00              NaN        S
# 16    2.00              NaN        Q
# 17     NaN              NaN        S
# 18   31.00              NaN        S
# 19     NaN              NaN        C
# 20   35.00              NaN        S
# 21   34.00              D56        S
# 22   15.00              NaN        Q
# 23   28.00               A6        S
# ...

# %% [markdown]
# #### Datatypes with floats or integer values

# %%
df[['Age', 'SibSp', 'Parch', 'Ticket', 'Fare']]
# Out:
#        Age  SibSp  Parch              Ticket      Fare
# 0    22.00      1      0           A/5 21171    7.2500
# 1    38.00      1      0            PC 17599   71.2833
# 2    26.00      0      0    STON/O2. 3101282    7.9250
# 3    35.00      1      0              113803   53.1000
# 4    35.00      0      0              373450    8.0500
# 5      NaN      0      0              330877    8.4583
# 6    54.00      0      0               17463   51.8625
# 7     2.00      3      1              349909   21.0750
# 8    27.00      0      2              347742   11.1333
# 9    14.00      1      0              237736   30.0708
# 10    4.00      1      1             PP 9549   16.7000
# 11   58.00      0      0              113783   26.5500
# 12   20.00      0      0           A/5. 2151    8.0500
# 13   39.00      1      5              347082   31.2750
# 14   14.00      0      0              350406    7.8542
# 15   55.00      0      0              248706   16.0000
# ...

# %% [markdown]
# ### Displaying first 5 and last 5 rows of the data

# %% [markdown]
# #### Displaying first 5 rows

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# #### Displaying last 5 rows

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# #### Transform Categorical values to numerical values

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Sex_code  Embarked_code
# 0      0         A/5 21171   7.2500   NaN        S         1              2
# 1      0          PC 17599  71.2833   C85        C         0              0
# 2      0  STON/O2. 3101282   7.9250   NaN        S         0              2
# ...

# %%
df["Sex_code"] = le.fit_transform(df.Sex)
df["Embarked_code"] = le.fit_transform(df.Embarked)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Sex_code  Embarked_code
# 0      0         A/5 21171   7.2500   NaN        S         1              2
# 1      0          PC 17599  71.2833   C85        C         0              0
# 2      0  STON/O2. 3101282   7.9250   NaN        S         0              2
# ...

# %% [markdown]
# ### Heatmap before NaN removal

# %%
sns.heatmap(df.corr())
# Out:
# /tmp/ipykernel_158127/58359773.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <AxesSubplot: >

# %% [markdown]
# ### Remove NaN, blank or empty values from data.

# %%
df.isnull().sum()
# Out:
# PassengerId        0
# Survived           0
# Pclass             0
# Name               0
# Sex                0
# Age              177
# SibSp              0
# Parch              0
# Ticket             0
# Fare               0
# Cabin            688
# Embarked           2
# Sex_code           0
# Embarked_code      0
# dtype: int64

# %%
df2 = df.dropna().head()
df2
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked  Sex_code  Embarked_code
# 1       0  PC 17599  71.2833   C85        C         0              0
# 3       0    113803  53.1000  C123        S         0              2
# 6       0     17463  51.8625   E46        S         1              2
# ...

# %% [markdown]
# ### Heatmap after NaN removal

# %%
sns.heatmap(df.corr())
# Out:
# /tmp/ipykernel_158127/58359773.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <AxesSubplot: >

# %% [markdown]
# ### Determining the mean of the data

# %%
df.mean()
# Out:
# /tmp/ipykernel_158127/3698961737.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# PassengerId      446.000000
# Survived           0.383838
# Pclass             2.308642
# Age               29.699118
# SibSp              0.523008
# Parch              0.381594
# Fare              32.204208
# Sex_code           0.647587
# Embarked_code      1.538721
# dtype: float64

# %% [markdown]
# ### Determining the median of the data

# %%
df.median()
# Out:
# /tmp/ipykernel_158127/530051474.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# PassengerId      446.0000
# Survived           0.0000
# Pclass             3.0000
# Age               28.0000
# SibSp              0.0000
# Parch              0.0000
# Fare              14.4542
# Sex_code           1.0000
# Embarked_code      2.0000
# dtype: float64

# %% [markdown]
# ### Determining the mode of the data

# %%
df.round(3).mode().head()
# Out:
#    PassengerId  Survived  Pclass                                   Name   Sex  \
# 0            1       0.0     3.0                    Abbing, Mr. Anthony  male
# 1            2       NaN     NaN            Abbott, Mr. Rossmore Edward   NaN
# 2            3       NaN     NaN       Abbott, Mrs. Stanton (Rosa Hunt)   NaN
# 3            4       NaN     NaN                    Abelson, Mr. Samuel   NaN
# 4            5       NaN     NaN  Abelson, Mrs. Samuel (Hannah Wizosky)   NaN
#
#     Age  SibSp  Parch    Ticket  Fare    Cabin Embarked  Sex_code  \
# 0  24.0    0.0    0.0      1601  8.05  B96 B98        S       1.0
# 1   NaN    NaN    NaN    347082   NaN       G6      NaN       NaN
# 2   NaN    NaN    NaN  CA. 2343   NaN      NaN      NaN       NaN
# 3   NaN    NaN    NaN       NaN   NaN      NaN      NaN       NaN
# 4   NaN    NaN    NaN       NaN   NaN      NaN      NaN       NaN
#
#    Embarked_code
# 0            2.0
# 1            NaN
# 2            NaN
# 3            NaN
# ...

# %% [markdown]
# ### Univariate bar chart analysis of the data

# %%
df.plot.bar(x="Name", y=["Sex_code", "Pclass", "Embarked_code"], rot=0)
# Out:
# <AxesSubplot: xlabel='Name'>

# %% [markdown]
# ### Bivariate analysis of the data using scatterplot

# %%
df.plot.scatter(x="Age", y="Survived", rot=0)
# Out:
# <AxesSubplot: xlabel='Age', ylabel='Survived'>
